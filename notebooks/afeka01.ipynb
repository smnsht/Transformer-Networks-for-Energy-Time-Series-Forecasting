# %% [markdown]
# # Transformer Networks for Energy Time Series Forecasting
#
# ## Lecture plan
#
# ### Brief intro to the challnge and importnece of electricity demand (./README.md)
#
# ### Introduction of the project obtained from the GitHub
# - overview of the dataset (afeka05)
# - overview of main.py + pipiline.py
# - overview of data-analysis.ipynb
